# %%
import pandas as pd
from datetime import datetime

# %%
sample = pd.DataFrame({
        'Date': ['02.12.2016 0:20', '03.12.2016 1:20', '03.12.2016 2:20'],
        'Value': [1, 2, 3]
})
sample
# Out:
#               Date  Value
# 0  02.12.2016 0:20      1
# 1  03.12.2016 1:20      2
# 2  03.12.2016 2:20      3

# %%
def truncate_date(row):
    row.Date = row.Date[0:10]
    return row
sample.apply(truncate_date, axis=1)
# Out:
#          Date  Value
# 0  02.12.2016      1
# 1  03.12.2016      2
# 2  03.12.2016      3

# %%
def convert_date(row):
    row.Date = datetime.strptime(row.Date, '%d.%m.%Y %H:%M').date()
    return row
sample.apply(convert_date, axis=1)
# Out:
#          Date  Value
# 0  2016-12-02      1
# 1  2016-12-03      2
# 2  2016-12-03      3
