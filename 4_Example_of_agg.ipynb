# %%
import pandas as pd

# %%
sample = pd.DataFrame({
    'A': ['Foo', 'Bar', 'Foo', 'Foo', 'Bar'],
    'B': [1, 2, 3, 4, 5],
})
sample
# Out:
#      A  B
# 0  Foo  1
# 1  Bar  2
# 2  Foo  3
# 3  Foo  4
# 4  Bar  5

# %%
def sum_square(x):
    return (x * x).sum()

# %%
sample.groupby('A').agg(['count', 'sum', sum_square])
# Out:
#         B
#     count sum sum_square
# A
# Bar     2   7         29
# Foo     3   8         26
